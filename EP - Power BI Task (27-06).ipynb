# %% [markdown]
# ## Understanding the Data

# %% [markdown]
# Import Libraries and Load Data

# %%
# Importing Libraries and Loading Data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("C:\The Algorithmic Vault\POWER BI\ELEVATE ASSIGNMENTS\electric_vehicles_spec_2025.csv.csv")

df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
# Dataset shape
print("Dataset Shape:", df.shape)

# List of columns
print("Column Names:", df.columns.tolist())
# Out:
# Dataset Shape: (478, 22)
# Column Names: ['brand', 'model', 'top_speed_kmh', 'battery_capacity_kWh', 'battery_type', 'number_of_cells', 'torque_nm', 'efficiency_wh_per_km', 'range_km', 'acceleration_0_100_s', 'fast_charging_power_kw_dc', 'fast_charge_port', 'towing_capacity_kg', 'cargo_volume_l', 'seats', 'drivetrain', 'segment', 'length_mm', 'width_mm', 'height_mm', 'car_body_type', 'source_url']

# %%
# View data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %% [markdown]
# #### Used this to understand:
#
# - This helps identify numerical vs categorical columns.
#
# - Check which columns have missing values.
#
# - Useful before visualizations or modeling.

# %%
# Descriptive statistics
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %% [markdown]
# #### Used this to understand:
#
# - Central tendency (mean, median)
#
# - Spread (std, min, max)
#
# - Outliers (via min/max values)

# %%
# Count missing values column-wise to identify which columns need imputation, cleaning, or can be dropped
df.isnull().sum()
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64

# %%
# Number of unique values per column to understand how many brands, models, body types, segments, etc., are present.
df.nunique()
# Out:
# brand                         59
# model                        477
# top_speed_kmh                 38
# battery_capacity_kWh         121
# battery_type                   1
# number_of_cells               38
# torque_nm                    128
# efficiency_wh_per_km         112
# range_km                      88
# acceleration_0_100_s          97
# fast_charging_power_kw_dc     71
# fast_charge_port               2
# towing_capacity_kg            26
# cargo_volume_l               140
# seats                          7
# drivetrain                     3
# segment                       15
# length_mm                    172
# width_mm                     108
# height_mm                    162
# car_body_type                  8
# source_url                   478
# dtype: int64

# %%
# Quick look at unique values of a few important columns
print("Car Body Types:", df["car_body_type"].unique(), '\n')
print("Segments:", df["segment"].unique(), '\n')
print("Drive Types:", df["drivetrain"].unique())
# Out:
# Car Body Types: ['Hatchback' 'SUV' 'Station/Estate' 'Liftback Sedan' 'Sedan'
#  'Small Passenger Van' 'Cabriolet' 'Coupe']
#
# Segments: ['B - Compact' 'JB - Compact' 'JC - Medium' 'JE - Executive' 'JD - Large'
#  'F - Luxury' 'D - Large' 'E - Executive' 'C - Medium' 'JF - Luxury'
#  'N - Passenger Van' 'A - Mini' 'JA - Mini' 'G - Sports' 'I - Luxury']
#
# Drive Types: ['FWD' 'RWD' 'AWD']

# %% [markdown]
# ## Data Cleaning

# %%
# Percentage of missing values
(df.isnull().sum() / len(df)) * 100
# Out:
# brand                         0.000000
# model                         0.209205
# top_speed_kmh                 0.000000
# battery_capacity_kWh          0.000000
# battery_type                  0.000000
# number_of_cells              42.259414
# torque_nm                     1.464435
# efficiency_wh_per_km          0.000000
# range_km                      0.000000
# acceleration_0_100_s          0.000000
# fast_charging_power_kw_dc     0.209205
# fast_charge_port              0.209205
# towing_capacity_kg            5.439331
# cargo_volume_l                0.209205
# seats                         0.000000
# drivetrain                    0.000000
# segment                       0.000000
# length_mm                     0.000000
# width_mm                      0.000000
# height_mm                     0.000000
# car_body_type                 0.000000
# source_url                    0.000000
# dtype: float64

# %% [markdown]
# #### Cleaning cargo_volume_l Column

# %%
banana_enteries = df['cargo_volume_l'].str.contains('Banana Boxes', na=False)

# %%
df.loc[banana_enteries, 'cargo_volume_l'] = np.nan

# %%
df['cargo_volume_l'] = pd.to_numeric(df['cargo_volume_l'], errors='coerce')

# %% [markdown]
# #### Imputing Missing Values

# %%
num_cols = df.select_dtypes(include='number')
cat_cols = df.select_dtypes(include='object')

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Checking data types and nulls again
print(df.dtypes, '\n')
print(df.isnull().sum())
# Out:
# brand                         object
# model                         object
# top_speed_kmh                  int64
# battery_capacity_kWh         float64
# battery_type                  object
# number_of_cells              float64
# torque_nm                    float64
# efficiency_wh_per_km           int64
# range_km                       int64
# acceleration_0_100_s         float64
# fast_charging_power_kw_dc    float64
# fast_charge_port              object
# towing_capacity_kg           float64
# cargo_volume_l               float64
# seats                          int64
# drivetrain                    object
# segment                       object
# length_mm                      int64
# width_mm                       int64
# height_mm                      int64
# car_body_type                 object
# source_url                    object
# dtype: object
#
# brand                        0
# model                        0
# top_speed_kmh                0
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# #### Correlation Analysis (Range vs Features)

# %%
# Selecting numeric columns to compare with range
num_cols = ["range_km", "battery_capacity_kWh", "efficiency_wh_per_km", 
            "fast_charging_power_kw_dc", "acceleration_0_100_s", "top_speed_kmh"]

# Ploting correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix: Range vs Key Features")
plt.show()

# %% [markdown]
# #### Scatter Plots – Relationship with Range

# %%
# Range vs Battery Capacity
sns.scatterplot(data=df, x="battery_capacity_kWh", y="range_km", hue="brand")
plt.title("Range vs Battery Capacity")
plt.show()

# Range vs Efficiency
sns.scatterplot(data=df, x="efficiency_wh_per_km", y="range_km")
plt.title("Range vs Efficiency (Lower = Better)")
plt.show()

# %% [markdown]
# ## Average Acceleration & Top Speed by Body Type

# %%
# Group by body type
grouped = df.groupby("car_body_type")[["acceleration_0_100_s", "top_speed_kmh"]].mean().sort_values(by="top_speed_kmh", ascending=False)

# Barplot
grouped.plot(kind="bar", figsize=(10,5))
plt.title("Avg Acceleration and Top Speed by Body Type")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Charging Speed vs Battery Size / Range

# %%
# Fast charging vs battery
sns.scatterplot(data=df, x="fast_charging_power_kw_dc", y="battery_capacity_kWh")
plt.title("Fast Charging Power vs Battery Size")
plt.show()

# Fast charging vs range
sns.scatterplot(data=df, x="fast_charging_power_kw_dc", y="range_km")
plt.title("Fast Charging Power vs Range")
plt.show()

# %% [markdown]
# #### Battery Size by Brand (Boxplot)

# %%
top_brands = df["brand"].value_counts().head(10).index
filtered = df[df["brand"].isin(top_brands)]

plt.figure(figsize=(12,6))
sns.boxplot(data=filtered, x="brand", y="battery_capacity_kWh")
plt.title("Battery Capacity Distribution by Top 10 Brands")
plt.xticks(rotation=45)
plt.show()

# %%
df.to_csv('cleaned_df.csv', index=False)
